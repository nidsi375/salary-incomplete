# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\GitBash\Files\Salaries.csv')
data.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
data.tail()
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035

# %%
data.sample()
# Out:
#           rank discipline  yrs.since.phd  yrs.service     sex  salary
# 316  AssocProf          B             12            9  Female   71065

# %%
data.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
data.shape
# Out:
# (397, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
data.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.scatterplot()
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="rank" ,y ="salary" ,data =data)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.scatterplot(x="discipline" ,y ="salary" ,data =data)
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='salary'>

# %%
sns.scatterplot(x="yrs.since.phd" ,y ="salary" ,data =data)
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %%
sns.scatterplot(x="yrs.service" ,y ="salary" ,data =data)
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='salary'>

# %%
sns.scatterplot(x="sex" ,y ="salary" ,data =data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='salary'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(data)
plt.savefig('img.png')
plt.show()

# %%
data.corr()
# Out:
#                yrs.since.phd  yrs.service    salary
# yrs.since.phd       1.000000     0.909649  0.419231
# yrs.service         0.909649     1.000000  0.334745
# salary              0.419231     0.334745  1.000000

# %%
 data.corr()['salary'].sort_values()
# Out:
# yrs.service      0.334745
# yrs.since.phd    0.419231
# salary           1.000000
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2, annot = True, fmt ="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# #
# correlation using HEATMAP

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(15,7))

sns.heatmap(data.corr(), annot=True, linewidths=0.5, linecolor="black" , fmt= '.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2, annot = True, fmt ="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.savefig('heatmap.png')
plt.show()

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(data.describe()[1:].transpose(),2),linewidth=2, annot = True, fmt ="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# ## OUTCOME OF CORRELATION

# %%
data.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %% [markdown]
# ## OUTCOME OF DESCRIBE OF DATASETS

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data.skew()
# Out:
# yrs.since.phd    0.300880
# yrs.service      0.650569
# salary           0.714568
# dtype: float64

# %%
sns.distplot(data["yrs.since.phd"])
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='Density'>

# %%
sns.distplot(data["yrs.service"])
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='Density'>

# %% [markdown]
# ## DATA CLEANING

# %%
data.corr()['salary']
# Out:
# yrs.since.phd    0.419231
# yrs.service      0.334745
# salary           1.000000
# Name: salary, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df = data.apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0     2           1             18           18    1     289
# 1     2           1             19           16    1     355
# 2     1           1              3            3    1      39
# 3     2           1             44           39    1     209
# 4     2           1             39           41    1     293

# %%
df.corr()['salary']
# Out:
# rank             0.566184
# discipline       0.166957
# yrs.since.phd    0.430239
# yrs.service      0.354403
# sex              0.130714
# salary           1.000000
# Name: salary, dtype: float64

# %% [markdown]
# ## OUTLIERS CHECKING

# %%
collist =df.columns.values
ncol=30
nrows=14

# %%
collist
# Out:
# array(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex',
#        'salary'], dtype=object)

# %%
for i in range (0, len(collist)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot( data =df[collist[i]], color ='green',orient='v')

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot( data =df[collist[i]], color ='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# ## SKEWNESS

# %%
df.skew()
# Out:
# rank            -1.151164
# discipline      -0.177684
# yrs.since.phd    0.275948
# yrs.service      0.552780
# sex             -2.709958
# salary           0.080231
# dtype: float64

# %% [markdown]
# #
# OUTCOME OF SKEWNESS.SKEWNESS THRESHOLD IS TAKEN +/- 0.5.COLUMS WITH THESES THRESHOL VALUE
# discipline
# yrs.since.phd
# yrs.service

# %% [markdown]
# ## NORMAL DISTRIBUTION CURVE

# %%
sns.distplot(df["rank"])
# Out:
# <AxesSubplot:xlabel='rank', ylabel='Density'>

# %%
sns.distplot(df["discipline"])
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='Density'>

# %%
sns.distplot(df["yrs.since.phd"])
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='Density'>

# %%
sns.distplot(df["yrs.service"])
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='Density'>

# %%
sns.distplot(df["sex"])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Density'>

# %% [markdown]
# #
# since "rank" ,"sex" and " discipline"has binomial distribution ,lets drop these columns

# %% [markdown]
# ## DATA CLEANING

# %%
df.corr()['salary']
# Out:
# rank             0.566184
# discipline       0.166957
# yrs.since.phd    0.430239
# yrs.service      0.354403
# sex              0.130714
# salary           1.000000
# Name: salary, dtype: float64

# %%
delete = pd.DataFrame([["0.566184","rank","No","Alot"],["0.166957","discipline","No","Alot"],["0.130714","sex","No","Alot"]],
                        columns=["Correlation with target","Column name","Normalised","Outliers"])
delete
# Out:
#   Correlation with target Column name Normalised Outliers
# 0                0.566184        rank         No     Alot
# 1                0.166957  discipline         No     Alot
# 2                0.130714         sex         No     Alot

# %%
df = df.drop(["rank","discipline","sex"], axis=1)
df
# Out:
#      yrs.since.phd  yrs.service  salary
# 0               18           18     289
# 1               19           16     355
# 2                3            3      39
# 3               44           39     209
# 4               39           41     293
# ..             ...          ...     ...
# 392             32           30     140
# 393             30           19     321
# 394             41           25     135
# 395             24           15     103
# 396              7            4      44
#
# [397 rows x 3 columns]

# %% [markdown]
# ## REMOVING OUTLIERS

# %%
    np.abs(zscore(df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25244/3299824929.py in <module>
# ----> 1 np.abs(zscore(df))
#
# NameError: name 'zscore' is not defined
